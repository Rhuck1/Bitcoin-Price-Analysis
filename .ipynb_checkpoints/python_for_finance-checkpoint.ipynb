# %% [markdown]
# # Python for Finance, Part I: Yahoo & Google Finance API, pandas, and matplotlib
#
# https://www.learndatasci.com/tutorials/python-finance-part-yahoo-finance-api-pandas-matplotlib/
#
# Implementation of short and long term rolling averages on data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
from pandas_datareader import data
plt.style.use('ggplot')

# %%
# Defunen the instruments to download. We Would like to see Apple, Microsoft and the S&P500 index
tickers = ['AAPL', 'MSFT', 'SPY', '^GSPC']

# We would like all available data form 01/01/2000 until 12/31/2016
start_date = '2010-01-01'
end_date = '2016-12-31'

# Use pandas_reader.data.Datareader to load the desired data
# panel_data = data.DataReader('INPX', data_source='yahoo', start=start_date, end=end_date)
panel_data = yf.download(tickers=tickers, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
type(panel_data)
# Out:
# pandas.core.frame.DataFrame

# %%
panel_data.head()
# Out:
#            Adj Close                                        Close             \
#                 AAPL       MSFT        SPY        ^GSPC      AAPL       MSFT
# Date
# 2010-01-04  6.572422  23.994564  90.493996  1132.989990  7.643214  30.950001
# 2010-01-05  6.583784  24.002319  90.733574  1136.520020  7.656429  30.959999
# 2010-01-06  6.479061  23.855013  90.797455  1137.140015  7.534643  30.770000
# 2010-01-07  6.467082  23.606922  91.180725  1141.689941  7.520714  30.450001
# 2010-01-08  6.510078  23.769743  91.484131  1144.979980  7.570714  30.660000
#
#                                          High             ...         Low  \
#                    SPY        ^GSPC      AAPL       MSFT  ...         SPY
# Date                                                      ...
# 2010-01-04  113.330002  1132.989990  7.660714  31.100000  ...  111.510002
# 2010-01-05  113.629997  1136.520020  7.699643  31.100000  ...  112.849998
# ...

# %%
panel_data['Close']['AAPL']
# Out:
# Date
# 2010-01-04     7.643214
# 2010-01-05     7.656429
# 2010-01-06     7.534643
# 2010-01-07     7.520714
# 2010-01-08     7.570714
#                 ...
# 2016-12-23    29.129999
# 2016-12-27    29.315001
# 2016-12-28    29.190001
# 2016-12-29    29.182501
# 2016-12-30    28.955000
# Name: AAPL, Length: 1762, dtype: float64

# %%
# Getting 
close = panel_data['Close'].copy()

# %%
close.describe()
# Out:
#               AAPL         MSFT          SPY        ^GSPC
# count  1762.000000  1762.000000  1762.000000  1762.000000
# mean     19.850671    37.129841   164.688053  1645.709499
# std       7.082699    10.810695    37.064206   371.293166
# min       6.858929    23.010000   102.199997  1022.580017
# 25%      13.862500    27.840000   131.302502  1310.224945
# 50%      19.608929    33.025000   165.269997  1650.489990
# 75%      25.773126    46.107500   201.972504  2020.782471
# max      33.250000    63.619999   227.759995  2271.719971

# %%
# Get the MSFT timeseries
msft = close.loc[:, 'MSFT']

# Calculate the 20 and 100 days moving average fo the closing prices
short_rolling_msft = msft.rolling(window=20).mean()
long_rolling_msft = msft.rolling(window=100).mean()

# Plot msft
fig, ax = plt.subplots(figsize=(16, 9))

ax.plot(msft.index, msft, label='MSFT', color='black')
ax.plot(short_rolling_msft.index, short_rolling_msft, label='20 days rolling', color='red')
ax.plot(long_rolling_msft.index, long_rolling_msft, label='100 days rolling', color='blue')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted Closing Price USD ($)')
ax.legend();

# %%
# Demonstrates what the data looks like in Scatter plot if line between consecutive points is not drawn

# Get the AAPL timeseries
msft = close.loc[:, 'AAPL']

# Calculate the 20 and 100 days moving average fo the closing prices
short_rolling_msft = msft.rolling(window=20).mean()
long_rolling_msft = msft.rolling(window=100).mean()

# Plot msft
fig, ax = plt.subplots(figsize=(16, 9))

ax.scatter(msft.index, msft, label='MSFT', color='black', s=3)
# ax.plot(short_rolling_msft.index, short_rolling_msft, label='20 days rolling', color='red')
# ax.plot(long_rolling_msft.index, long_rolling_msft, label='100 days rolling', color='blue')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted Closing Price USD ($)')
ax.legend();
